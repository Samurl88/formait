# %%
import os
import cv2
from IPython.display import display_html, display
from PIL import Image as PILImage
# from utils import display_borderless_tables

from img2table.document import Image, PDF
from img2table.ocr import TesseractOCR, PaddleOCR

# %%
img = PDF("unfi.pdf")

# %%
tesseract = TesseractOCR()

# Extract tables with Tesseract and PaddleOCR
tables = img.extract_tables(ocr=tesseract, borderless_tables=True)

tables[0][0].df
# Out:
# tesseract 5.4.1
#  leptonica-1.84.1
#   libgif 5.2.1 : libjpeg 8d (libjpeg-turbo 3.0.0) : libpng 1.6.43 : libtiff 4.6.0 : zlib 1.2.12 : libwebp 1.4.0 : libopenjp2 2.5.2
#  Found NEON
#  Found libarchive 3.7.4 zlib/1.2.12 liblzma/5.4.6 bz2lib/1.0.8 liblz4/1.9.4 libzstd/1.5.6
#  Found libcurl/8.6.0 SecureTransport (LibreSSL/3.3.6) zlib/1.2.12 nghttp2/1.61.0
# /Users/samuel/opt/anaconda3/lib/python3.9/site-packages/img2table/tables/processing/bordered_tables/cells/identification.py:17: PerformanceWarning: Determining the column names of a LazyFrame requires resolving its schema, which is a potentially expensive operation. Use `LazyFrame.collect_schema().names()` to get the column names without this warning.
#   .rename({col: f"{col}_" for col in df_h_lines.columns})
# /Users/samuel/opt/anaconda3/lib/python3.9/site-packages/img2table/tables/processing/bordered_tables/cells/deduplication.py:21: PerformanceWarning: Determining the column names of a LazyFrame requires resolving its schema, which is a potentially expensive operation. Use `LazyFrame.collect_schema().names()` to get the column names without this warning.
#   .rename({col: f"{col}_" for col in df_cells.columns})
#          0                  1                         2     3  \
# 0  Vendor:                SUN      TROPICS/ABC BEV/CHIL  Ship
# 1     None                123                Drinks Way   To:
# 2     None               None  509-747-7447 Jack London  None
# 3     None  SPOKANE, WA 99224         SPOKANE, WA 99224  None
#
#                          4
# 0  UNFI - Dublin, CA Appt:
# 1        dubappts@unfi.com
# 2   4000 Inspiration Drive
# 3         Dublin, CA 94568

# %%
tables[0][1].df
# Out:
#                                                     0  \
# 0                             MIN 150 MASTER - NO MAX
# 1                        Pls confirm SHIP/PU DATE by:
# 2                                              Phone:
# 3                                             or FAX:
# 4                                             o\nr\n:
# 5   **********************************************...
# 6                                     Buyer *\nP.O. #
# 7                              * John Smith\n2000-002
# 8   **********************************************...
# 9                                 Created *\nShip Via
# 10                               * 08/01/24\nSUPPLIER
#
#                                                     1  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5   **********************************************...
# 6                                                None
# 7                                                None
# 8   **********************************************...
# 9                                              F.O.B.
# 10                                               None
#
#                                                     2  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5   **********************************************...
# 6                                             Vendor#
# 7                                            G-829355
# 8   **********************************************...
# 9                                                None
# 10                                               None
#
#                                                     3  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5   **********************************************...
# 6                                                Page
# 7                                                None
# 8   **********************************************...
# 9                                               Terms
# 10                                               1\n%
#
#                                                     4  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5   **********************************************...
# 6                                                Page
# 7                                                   1
# 8   **********************************************...
# 9                                               Terms
# 10                                               1\n0
#
#                                                     5  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5   **********************************************...
# 6                                                None
# 7                                         PURCH ORDER
# 8   **********************************************...
# 9                                                None
# 10                                                NET
#
#                                                     6  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5   **********************************************...
# 6                                                None
# 7                                         PURCH ORDER
# 8   **********************************************...
# 9                                                None
# 10                                               1\n5
#
#                                                     7  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5   **********************************************...
# 6                                                None
# 7                                                None
# 8   **********************************************...
# 9                                                Tax*
# 10                                                  N
#
#                                                     8
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5   **********************************************...
# 6                                                   *
# 7                                                   *
# 8   **********************************************...
# 9                                                Tax*
# 10                                                  *

# %%
tables[0][2].df
# Out:
#      0    1      2     3      4            5                     6      7   \
# 0  Line  Qty  Cases  Plts  Prod#  Description           Description  Units
# 1     1  150    150     2  10827          S T          MANGO NECTAR   8/64
# 2     2   75     75     1  10829          s T          GUAVA NECTAR   8/64
# 3     3   45     45  0.60  82058          s T  CALAMANSI LIM NECTAR   8/64
# 4     4   75     75     1  11311          s T  PASSN/ORNG/GUAVA JCE   8/64
#
#       8       9     10              11              12
# 0  Units  Vendor  P.N.  Cost Extension  Cost Extension
# 1     oz   02420  None          300.00        45000.00
# 2     oz   02421  None          350.00        26250.00
# 3     oz  100262  None          400.00        18000.00
# 4     oz   10068  None          450.00        33750.00
